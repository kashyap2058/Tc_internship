# %%
# Import pandas
import pandas as pd

# %%
# Create a series of three different colours

# %%
# View the series of different colours
colors=pd.Series(['Red','Green','Blue'])
colors
# Out:
# 0      Red
# 1    Green
# 2     Blue
# dtype: object

# %%
# Create a series of three different car types and view it
car=pd.Series(['Porche','Mclaren','Ferrari'])
car
# Out:
# 0     Porche
# 1    Mclaren
# 2    Ferrari
# dtype: object

# %%
# Combine the Series of cars and colours into a DataFrame
combine={'Car':car,
        'Colors':colors}
data=pd.DataFrame(combine)
data
# Out:
#        Car Colors
# 0   Porche    Red
# 1  Mclaren  Green
# 2  Ferrari   Blue

# %%
# Import "../car-sales.csv" and turn it into a DataFrame
df=pd.read_csv('car-sales.csv')
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %% [markdown]
# :**Note:** Since you've imported `../car-sales.csv` as a DataFrame, we'll now refer to this DataFrame as 'the car sales DataFrame'.

# %%
# Export the DataFrame you created to a .csv file
df.to_csv('Test_data.csv')

# %%
# Find the different datatypes of the car data DataFrame
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Describe your current car sales DataFrame using describe()
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# Get information about your DataFrame using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %% [markdown]
# What does it show you?<br>
# it shows us that there are 3 categorical features and 2 numeric features in the dataframe

# %%
# Create a Series of different numbers and find the mean of them
num=pd.Series([1,2,3,4,5])
num.mean()
# Out:
# 3.0

# %%
# Create a Series of different numbers and find the sum of them
num.sum()
# Out:
# 15

# %%
# List out all the column names of the car sales DataFrame
df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# Find the length of the car sales DataFrame
len(df)
# Out:
# 10

# %%
# Show the first 5 rows of the car sales DataFrame
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of the car sales DataFrame
df.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Show the bottom 5 rows of the car sales DataFrame
df.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame
df.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame
df.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# Notice how they're the same? Why do you think this is?
#
# Check the pandas documentation for [.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) and [.iloc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html). Think about a different situation each could be used for and try them out.

# %% [markdown]
# the df.loc and df.iloc are both same in this case because in df.loc as the label given is an integer and also in df.iloc, the index is integer so they both are same

# %% [markdown]
# however using df.loc, we can provide on integer values as lalbel whereas in df.iloc, we can only pass integer values or index values

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame
df['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame
df['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
# Select the rows with over 100,000 kilometers on the Odometer
df.loc[df['Odometer (KM)']>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Create a crosstab of the Make and Doors columns
pd.crosstab(df['Make'],df['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group columns of the car sales DataFrame by the Make column and find the average
df.groupby('Make').mean()
# Out:
# C:\Users\Kashyap Ghimire\AppData\Local\Temp\ipykernel_20548\129070492.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Make').mean()
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Import Matplotlib and create a plot of the Odometer column
# Don't forget to use %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(df['Odometer (KM)'], marker='o')
plt.title('Odometer Readings')
plt.xlabel('Index')
plt.ylabel('Odometer')
plt.grid(True)
plt.show()

# %%
# Create a histogram of the Odometer column using hist()
plt.hist(df['Odometer (KM)'])
# Out:
# (array([1., 3., 2., 1., 1., 0., 1., 0., 0., 1.]),
#  array([ 11179. ,  31370.6,  51562.2,  71753.8,  91945.4, 112137. ,
#         132328.6, 152520.2, 172711.8, 192903.4, 213095. ]),
#  <BarContainer object of 10 artists>)

# %%
# Try to plot the Price column using plot()
df['Price']
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %% [markdown]
# Why didn't it work? Can you think of a solution?
#
# You might want to search for "how to convert a pandas string column to numbers".
#
# And if you're still stuck, check out this [Stack Overflow question and answer on turning a price column into integers](https://stackoverflow.com/questions/44469313/price-column-object-to-int-in-pandas).
#
# See how you can provide the example code there to the problem here.

# %% [markdown]
# we cant plot the price column because it is in string format which can't be interpreted by matplotlib

# %%
# Remove the punctuation from price column
import string
df['Price']=df['Price'].apply(lambda x: ''.join([char for char in x if char not in ['$',',']]))
df
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   4000.00
# 1   Honda    Red          87899      4   5000.00
# 2  Toyota   Blue          32549      3   7000.00
# 3     BMW  Black          11179      5  22000.00
# 4  Nissan  White         213095      4   3500.00
# 5  Toyota  Green          99213      4   4500.00
# 6   Honda   Blue          45698      4   7500.00
# 7   Honda   Blue          54738      4   7000.00
# 8  Toyota  White          60000      4   6250.00
# 9  Nissan  White          31600      4   9700.00

# %%
# Check the changes to the price 
df['Price']
# Out:
# 0     4000.00
# 1     5000.00
# 2     7000.00
# 3    22000.00
# 4     3500.00
# 5     4500.00
# 6     7500.00
# 7     7000.00
# 8     6250.00
# 9     9700.00
# Name: Price, dtype: object

# %%
# Remove the two extra zeros at the end of the price column
def remove_dot(x):
    return x[0:x.index('.')]
df['Price']=df['Price'].apply(remove_dot)
df['Price']
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: object

# %%
# Check the changes to the Price column
type(df['Price'].loc[1][0])
# Out:
# str

# %%
# Change the datatype of the Price column to integers
df['Price']=df['Price'].apply(lambda x: int(x))
df['Price']
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int64

# %%
# Lower the strings of the Make column

# %% [markdown]
# If you check the car sales DataFrame, you'll notice the Make column hasn't been lowered.
#
# How could you make these changes permanent?
#
# Try it out.

# %%
# Make lowering the case of the Make column permanent
df['Make']=df['Make'].apply(lambda x: x.lower())
df['Make']
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
# Check the car sales DataFrame
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %% [markdown]
# Notice how the Make column stays lowered after reassigning.
#
# Now let's deal with missing data.

# %%
# Import the car sales DataFrame with missing data ("../car-sales-missing-data.csv")
df1=pd.read_csv('car-sales-missing-data.csv')

# Check out the new DataFrame"
df1
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# Notice the missing values are represented as `NaN` in pandas DataFrames.
#
# Let's try fill them.

# %%
# Fill the Odometer column missing values with the mean of the column inplace
df1['Odometer'].fillna(df1['Odometer'].mean(),inplace=True)

# %%
# View the car sales missing DataFrame and verify the changes
df1
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# Remove the rest of the missing data inplace
df1.fillna(df1.mean(),inplace=True)
# Out:
# C:\Users\Kashyap Ghimire\AppData\Local\Temp\ipykernel_20548\1891226706.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.fillna(df1.mean(),inplace=True)

# %%
# Verify the missing values are removed by viewing the DataFrame
df1
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# We'll now start to add columns to our DataFrame.

# %%
# Create a "Seats" column where every row has a value of 5
df1['Seats']=5

# %%
# Create a column called "Engine Size" with random values between 1.3 and 4.5
# Remember: If you're doing it from a Python list, the list has to be the same length
# as the DataFrame
import random
df1['Engine Size']=[random.uniform(1.3,4.5) for _ in range(df.shape[0])]
df1
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   $4,000      5     4.061116
# 1   Honda    Red   87899.000000    4.0   $5,000      5     3.804869
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5     2.270210
# 3     BMW  Black   11179.000000    5.0  $22,000      5     3.208956
# 4  Nissan  White  213095.000000    4.0   $3,500      5     4.482107
# 5  Toyota  Green   92302.666667    4.0   $4,500      5     1.641312
# 6   Honda    NaN   92302.666667    4.0   $7,500      5     1.858895
# 7   Honda   Blue   92302.666667    4.0      NaN      5     2.474649
# 8  Toyota  White   60000.000000    4.0      NaN      5     1.314064
# 9     NaN  White   31600.000000    4.0   $9,700      5     3.990636

# %%
#filling in the price values in df1
#replacing punctuations
import re
def preprocess(x):
#     print(type(x))
    if str(x) != 'nan':
        return int(re.sub(r'[$,]', '', x))
    else:
        return None
df1['Price']=df1['Price'].apply(preprocess)
df1
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   4000.0      5     4.061116
# 1   Honda    Red   87899.000000    4.0   5000.0      5     3.804869
# 2  Toyota   Blue   92302.666667    3.0   7000.0      5     2.270210
# 3     BMW  Black   11179.000000    5.0  22000.0      5     3.208956
# 4  Nissan  White  213095.000000    4.0   3500.0      5     4.482107
# 5  Toyota  Green   92302.666667    4.0   4500.0      5     1.641312
# 6   Honda    NaN   92302.666667    4.0   7500.0      5     1.858895
# 7   Honda   Blue   92302.666667    4.0      NaN      5     2.474649
# 8  Toyota  White   60000.000000    4.0      NaN      5     1.314064
# 9     NaN  White   31600.000000    4.0   9700.0      5     3.990636

# %%
type(df1['Price'][0])
# Out:
# numpy.float64

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame
df1['Price/Km']=df1['Price']/df1['Odometer']
df1
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size  Price/Km
# 0  Toyota  White  150043.000000    4.0   4000.0      5     4.061116  0.026659
# 1   Honda    Red   87899.000000    4.0   5000.0      5     3.804869  0.056883
# 2  Toyota   Blue   92302.666667    3.0   7000.0      5     2.270210  0.075837
# 3     BMW  Black   11179.000000    5.0  22000.0      5     3.208956  1.967976
# 4  Nissan  White  213095.000000    4.0   3500.0      5     4.482107  0.016425
# 5  Toyota  Green   92302.666667    4.0   4500.0      5     1.641312  0.048753
# 6   Honda    NaN   92302.666667    4.0   7500.0      5     1.858895  0.081254
# 7   Honda   Blue   92302.666667    4.0   7900.0      5     2.474649  0.085588
# 8  Toyota  White   60000.000000    4.0   7900.0      5     1.314064  0.131667
# 9     NaN  White   31600.000000    4.0   9700.0      5     3.990636  0.306962

# %%
# Remove the last column you added using .drop()
df1.drop(['Price/Km'],axis=1)
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   4000.0      5     4.061116
# 1   Honda    Red   87899.000000    4.0   5000.0      5     3.804869
# 2  Toyota   Blue   92302.666667    3.0   7000.0      5     2.270210
# 3     BMW  Black   11179.000000    5.0  22000.0      5     3.208956
# 4  Nissan  White  213095.000000    4.0   3500.0      5     4.482107
# 5  Toyota  Green   92302.666667    4.0   4500.0      5     1.641312
# 6   Honda    NaN   92302.666667    4.0   7500.0      5     1.858895
# 7   Honda   Blue   92302.666667    4.0   7900.0      5     2.474649
# 8  Toyota  White   60000.000000    4.0   7900.0      5     1.314064
# 9     NaN  White   31600.000000    4.0   9700.0      5     3.990636

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable
shuffled_df = df1.sample(frac=1)
shuffled_df
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size  Price/Km
# 8  Toyota  White   60000.000000    4.0   7900.0      5     1.314064  0.131667
# 0  Toyota  White  150043.000000    4.0   4000.0      5     4.061116  0.026659
# 1   Honda    Red   87899.000000    4.0   5000.0      5     3.804869  0.056883
# 5  Toyota  Green   92302.666667    4.0   4500.0      5     1.641312  0.048753
# 2  Toyota   Blue   92302.666667    3.0   7000.0      5     2.270210  0.075837
# 3     BMW  Black   11179.000000    5.0  22000.0      5     3.208956  1.967976
# 9     NaN  White   31600.000000    4.0   9700.0      5     3.990636  0.306962
# 6   Honda    NaN   92302.666667    4.0   7500.0      5     1.858895  0.081254
# 4  Nissan  White  213095.000000    4.0   3500.0      5     4.482107  0.016425
# 7   Honda   Blue   92302.666667    4.0   7900.0      5     2.474649  0.085588

# %% [markdown]
# Notice how the index numbers get moved around. The [`sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) function is a great way to get random samples from your DataFrame. It's also another great way to shuffle the rows by setting `frac=1`.

# %%
# Reset the indexes of the shuffled DataFrame
shuffled_df.reset_index(drop=True, inplace=True)
shuffled_df
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size  Price/Km
# 0  Toyota  White   60000.000000    4.0   7900.0      5     1.314064  0.131667
# 1  Toyota  White  150043.000000    4.0   4000.0      5     4.061116  0.026659
# 2   Honda    Red   87899.000000    4.0   5000.0      5     3.804869  0.056883
# 3  Toyota  Green   92302.666667    4.0   4500.0      5     1.641312  0.048753
# 4  Toyota   Blue   92302.666667    3.0   7000.0      5     2.270210  0.075837
# 5     BMW  Black   11179.000000    5.0  22000.0      5     3.208956  1.967976
# 6     NaN  White   31600.000000    4.0   9700.0      5     3.990636  0.306962
# 7   Honda    NaN   92302.666667    4.0   7500.0      5     1.858895  0.081254
# 8  Nissan  White  213095.000000    4.0   3500.0      5     4.482107  0.016425
# 9   Honda   Blue   92302.666667    4.0   7900.0      5     2.474649  0.085588

# %% [markdown]
# Notice the index numbers have been changed to have order (start from 0).

# %%
# Change the Odometer values from kilometers to miles using a Lambda function
# Then view the DataFrame
shuffled_df['Odometer']=shuffled_df['Odometer'].apply(lambda x: x*0.621)

# %%
# Change the title of the Odometer (KM) to represent miles instead of kilometers
shuffled_df.rename(columns={'Odometer': 'Odometer (miles)'}, inplace=True)
shuffled_df
# Out:
#      Make Colour  Odometer (miles)  Doors    Price  Seats  Engine Size  \
# 0  Toyota  White         37260.000    4.0   7900.0      5     1.314064
# 1  Toyota  White         93176.703    4.0   4000.0      5     4.061116
# 2   Honda    Red         54585.279    4.0   5000.0      5     3.804869
# 3  Toyota  Green         57319.956    4.0   4500.0      5     1.641312
# 4  Toyota   Blue         57319.956    3.0   7000.0      5     2.270210
# 5     BMW  Black          6942.159    5.0  22000.0      5     3.208956
# 6     NaN  White         19623.600    4.0   9700.0      5     3.990636
# 7   Honda    NaN         57319.956    4.0   7500.0      5     1.858895
# 8  Nissan  White        132331.995    4.0   3500.0      5     4.482107
# 9   Honda   Blue         57319.956    4.0   7900.0      5     2.474649
#
#    Price/Km
# 0  0.131667
# 1  0.026659
# 2  0.056883
# 3  0.048753
# 4  0.075837
# 5  1.967976
# 6  0.306962
# 7  0.081254
# 8  0.016425
# 9  0.085588

# %%
# concat dataframe for car-sales-missing and car-sales
pd.concat([df,df1])
# Out:
#      Make Colour  Odometer (KM)  Doors    Price       Odometer  Seats  \
# 0  toyota  White       150043.0    4.0   4000.0            NaN    NaN
# 1   honda    Red        87899.0    4.0   5000.0            NaN    NaN
# 2  toyota   Blue        32549.0    3.0   7000.0            NaN    NaN
# 3     bmw  Black        11179.0    5.0  22000.0            NaN    NaN
# 4  nissan  White       213095.0    4.0   3500.0            NaN    NaN
# 5  toyota  Green        99213.0    4.0   4500.0            NaN    NaN
# 6   honda   Blue        45698.0    4.0   7500.0            NaN    NaN
# 7   honda   Blue        54738.0    4.0   7000.0            NaN    NaN
# 8  toyota  White        60000.0    4.0   6250.0            NaN    NaN
# 9  nissan  White        31600.0    4.0   9700.0            NaN    NaN
# 0  Toyota  White            NaN    4.0   4000.0  150043.000000    5.0
# 1   Honda    Red            NaN    4.0   5000.0   87899.000000    5.0
# ...

# %%
# Assigning Keys to the Concatenated DataFrame Indexes
pd.concat([df,df1],keys=['df1','df2'])
# Out:
#          Make Colour  Odometer (KM)  Doors    Price       Odometer  Seats  \
# df1 0  toyota  White       150043.0    4.0   4000.0            NaN    NaN
#     1   honda    Red        87899.0    4.0   5000.0            NaN    NaN
#     2  toyota   Blue        32549.0    3.0   7000.0            NaN    NaN
#     3     bmw  Black        11179.0    5.0  22000.0            NaN    NaN
#     4  nissan  White       213095.0    4.0   3500.0            NaN    NaN
#     5  toyota  Green        99213.0    4.0   4500.0            NaN    NaN
#     6   honda   Blue        45698.0    4.0   7500.0            NaN    NaN
#     7   honda   Blue        54738.0    4.0   7000.0            NaN    NaN
#     8  toyota  White        60000.0    4.0   6250.0            NaN    NaN
#     9  nissan  White        31600.0    4.0   9700.0            NaN    NaN
# df2 0  Toyota  White            NaN    4.0   4000.0  150043.000000    5.0
#     1   Honda    Red            NaN    4.0   5000.0   87899.000000    5.0
# ...

# %%
# merge dataframe for car-sales-missing and car-sales based on key 'Make', apply all join methods
# Merge using inner join
inner_join = pd.merge(df,df1, on='Make', how='inner')
print("Inner Join:")
print(inner_join)
print()

# Merge using outer join
outer_join = pd.merge(df,df1, on='Make', how='outer')
print("Outer Join:")
print(outer_join)
print()

# Merge using left join
left_join = pd.merge(df,df1, on='Make', how='left')
print("Left Join:")
print(left_join)
print()

# Merge using right join
right_join = pd.merge(df,df1, on='Make', how='right')
print("Right Join:")
print(right_join)
# Out:
# Inner Join:
# Empty DataFrame
# Columns: [Make, Colour_x, Odometer (KM), Doors_x, Price_x, Colour_y, Odometer, Doors_y, Price_y, Seats, Engine Size, Price/Km]
# Index: []
#
# Outer Join:
#       Make Colour_x  Odometer (KM)  Doors_x  Price_x Colour_y       Odometer  \
# 0   toyota    White       150043.0      4.0   4000.0      NaN            NaN
# 1   toyota     Blue        32549.0      3.0   7000.0      NaN            NaN
# 2   toyota    Green        99213.0      4.0   4500.0      NaN            NaN
# 3   toyota    White        60000.0      4.0   6250.0      NaN            NaN
# 4    honda      Red        87899.0      4.0   5000.0      NaN            NaN
# 5    honda     Blue        45698.0      4.0   7500.0      NaN            NaN
# 6    honda     Blue        54738.0      4.0   7000.0      NaN            NaN
# 7      bmw    Black        11179.0      5.0  22000.0      NaN            NaN
# 8   nissan    White       213095.0      4.0   3500.0      NaN            NaN
# ...
